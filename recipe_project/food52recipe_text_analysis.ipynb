# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
% matplotlib inline

# %%
df = pd.read_csv('data/food52_scraped_data.csv')

# %%
df.head()
# Out:
#                         _id  rating  \
# 0  59d7cf29a980892888190548      14
# 1  59d7cf30a98089288819054a      29
# 2  59d7cf39a98089288819054c       2
# 3  59d7cf3fa98089288819054e      92
# 4  59d7cf48a980892888190550       3
#
#                                               recipe  \
# 0  2 tablespoons unsalted butter\n1/4 cup diced y...
# 1  1 pound shelled raw peanuts\n1 tablespoon plus...
# 2  2 cups (8 1/2 ounces) all-purpose flour\n1/2 c...
# 3  1 1/2 cups (300g) Puy lentils, washed\n4 clove...
# 4  2 ounces Seedlip Garden 108\n0.75 ounces Lemon...
#
#                                                title  \
# 0                           Austin Diner-Style Queso
# 1                Mamba (Spicy Haitian Peanut Butter)
# 2                                  Sheet Pan Muffins
# 3  Anna Jones' Favorite Lentils with Roasted Toma...
# 4                              Seedlip's A Good Dill
#
#                                              weblink
# 0  https://food52.com/recipes/73529-austin-diner-...
# 1  https://food52.com/recipes/73211-mamba-spicy-h...
# 2  https://food52.com/recipes/73548-sheet-pan-muf...
# 3  https://food52.com/recipes/73511-anna-jones-fa...
# 4  https://food52.com/recipes/73252-seedlip-s-a-g...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9233 entries, 0 to 9714
# Data columns (total 5 columns):
# _id        9233 non-null object
# rating     9233 non-null int64
# recipe     9233 non-null object
# title      9233 non-null object
# weblink    9233 non-null object
# dtypes: int64(1), object(4)
# memory usage: 432.8+ KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from time import time
import seaborn as sns

# %%
def topic_extraction(df, col_name):
    """
    Two algorithms for topic extraction -
    NMF and LatentDirichletAllocation(LDA).
    Need to tie in with K-means clustering
    """

    tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                       max_features=200,
                                       stop_words='english')
    tfidf = tfidf_vectorizer.fit_transform(df[col_name])
    tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                    max_features=200,
                                    stop_words='english')
    tf = tf_vectorizer.fit_transform(df[col_name])

    nmf = NMF(n_components=10, random_state=1,
            alpha=.1, l1_ratio=.5)
    tfidf_feature_names = tfidf_vectorizer.get_feature_names()
    nmf_w = nmf.fit_transform(tfidf)
    nmf_h = nmf.components_
    df['labels'] = nmf_w.argmax(axis=1) # this was the right code to get labels/clusters
    labels = df['labels'].values

    # tsne_algorithm(tfidf) # feed the tsne algorithm
    # sns.distplot(df['labels'], kde=True)
    # plt.show()
    print("\nTopics in NMF model:")
    print_top_words(nmf, tfidf_feature_names)
#     clustering_algorithm(nmf_w_short, labels)
    """uncomment to LDA topics"""
    lda = LatentDirichletAllocation(n_components=10, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0,
                                n_jobs=-1)
    mod = lda.fit(tf)
    comp = mod.fit_transform(tf)
    lda_labels = comp.argmax(axis=1)
    df['lda_topics'] = lda_labels
    print("\nTopics in LDA model:")
    tf_feature_names = tf_vectorizer.get_feature_names()
    print_top_words(lda, tf_feature_names)
    
    return df, labels, lda_labels, tfidf, tf
    

def print_top_words(model, feature_names, n_top_words=20):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print('End')

# %%
df, labels, lda_labels, tfidf, tf = topic_extraction(df, 'recipe')
# Out:
# Topics in NMF model:
# Topic #0:
# chopped diced finely onion chicken tomatoes red minced medium garlic fresh cloves pepper small large celery taste parsley pound beef
# Topic #1:
# sugar butter flour baking vanilla unsalted purpose teaspoon extract tablespoons egg eggs milk room temperature powder cup granulated soda salt
# Topic #2:
# grams piece flour coconut pieces pinch yeast oil sugar plus water fine finely grated egg 10 handful olive chocolate seeds
# Topic #3:
# teaspoon ground powder pepper teaspoons black cumin dried paprika cinnamon salt cayenne coriander seeds chili garlic freshly tablespoon kosher pound
# Topic #4:
# sauce tablespoon tablespoons soy sesame minced ginger rice vinegar oil garlic sugar chicken teaspoons brown pork lime pounds cloves honey
# Topic #5:
# olive lemon tablespoons oil fresh pepper extra juice salt virgin freshly black taste tablespoon kosher sea garlic ground leaves zest
# Topic #6:
# cup cheese grated milk cream sugar heavy shredded coconut parmesan toasted syrup white honey vinegar water packed maple fresh juice
# Topic #7:
# ounces ounce cheese 12 cream lime chocolate 10 garnish 14 orange syrup 15 shredded grated juice heavy slices mushrooms parmesan
# Topic #8:
# cups water flour yeast teaspoons purpose cold salt dry vegetable plus oil rice chicken needed broth cooked kosher stock white
# Topic #9:
# sliced cut inch pieces thinly peeled large half chicken slices small medium pounds red white pepper onion cubes pound potatoes
# End
#
# Topics in LDA model:
# Topic #0:
# chopped cups cup diced chicken onion pepper large peeled garlic salt oil medium red tablespoons fresh cloves small stock cut
# Topic #1:
# cup cheese ounces sliced grated fresh slices pepper chopped pound salt thinly parmesan shredded bread oil bacon olive cups butter
# Topic #2:
# cup cut tablespoons oil olive extra salt inch chopped virgin half small taste pieces plus divided fresh cubes tablespoon large
# Topic #3:
# grams ounces ounce 15 12 14 10 water garnish chocolate sugar orange optional dry white pinch egg syrup chopped salt
# Topic #4:
# cup tablespoons cream sugar butter syrup heavy cups maple cinnamon brown tablespoon milk unsalted pinch ground stick salt nutmeg light
# Topic #5:
# teaspoon ground pepper tablespoons salt tablespoon black garlic teaspoons minced oil cup freshly olive cloves dried onion red chopped pound
# Topic #6:
# cup flour cups tablespoons salt butter teaspoon water purpose unsalted sugar plus teaspoons egg tablespoon cold room temperature milk eggs
# Topic #7:
# juice lemon cup fresh zest tablespoon teaspoon apple lime tablespoons vinegar orange cider sliced sugar salt leaves thinly mint teaspoons
# Topic #8:
# teaspoon cup powder sugar baking cups salt flour ground vanilla teaspoons coconut cinnamon extract soda milk brown chopped butter eggs
# Topic #9:
# tablespoons sauce tablespoon cup oil chicken teaspoon garlic soy ginger rice minced sesame boneless chopped teaspoons sliced skinless pieces sugar
# End

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
def clustering_algorithm(tfidf, labels):

    svd = TruncatedSVD(algorithm='randomized', random_state=42)
    X_new = svd.fit_transform(tfidf)
    tsne_mod = TSNE(n_components=3, verbose=1, random_state=0, perplexity=40)
    coords = tsne_mod.fit_transform(X_new)
    x, y, z = coords[:, 0], coords[:, 1], coords[:, 2]
    return x, y, z

# %%
x, y, z = clustering_algorithm(tfidf, labels)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9233 samples in 0.013s...
# [t-SNE] Computed neighbors for 9233 samples in 0.331s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9233
# [t-SNE] Computed conditional probabilities for sample 2000 / 9233
# [t-SNE] Computed conditional probabilities for sample 3000 / 9233
# [t-SNE] Computed conditional probabilities for sample 4000 / 9233
# [t-SNE] Computed conditional probabilities for sample 5000 / 9233
# [t-SNE] Computed conditional probabilities for sample 6000 / 9233
# [t-SNE] Computed conditional probabilities for sample 7000 / 9233
# [t-SNE] Computed conditional probabilities for sample 8000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9233 / 9233
# [t-SNE] Mean sigma: 0.009631
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.997391
# [t-SNE] Error after 1000 iterations: 0.595946

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, zdir='z', c=labels, s=20, cmap='Dark2', alpha=0.4)
ax.set_title('TSNE analysis of Recipe Ingredients - NMF labels', fontsize=14, fontweight='bold')
ax.grid(False)
# plt.savefig('data/title_tsne.png')

# %%
x2, y2, z2 = clustering_algorithm(tf, labels)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9233 samples in 0.014s...
# [t-SNE] Computed neighbors for 9233 samples in 0.314s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9233
# [t-SNE] Computed conditional probabilities for sample 2000 / 9233
# [t-SNE] Computed conditional probabilities for sample 3000 / 9233
# [t-SNE] Computed conditional probabilities for sample 4000 / 9233
# [t-SNE] Computed conditional probabilities for sample 5000 / 9233
# [t-SNE] Computed conditional probabilities for sample 6000 / 9233
# [t-SNE] Computed conditional probabilities for sample 7000 / 9233
# [t-SNE] Computed conditional probabilities for sample 8000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9233 / 9233
# [t-SNE] Mean sigma: 0.108035
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.890099
# [t-SNE] Error after 1000 iterations: 0.583661

# %%
""" LDA labels used to identify points in scatter plot of t-SNE analysis of recipe text"""
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x2, y2, z2, zdir='z', c=lda_labels, s=20, cmap='Dark2', alpha=0.4)
ax.set_title('TSNE analysis of Recipe Ingredients - LDA labels', fontsize=14, fontweight='bold')
ax.grid(False)
# plt.savefig('data/title_tsne.png')

# %%
df['lda_topics'].value_counts()
# Out:
# 0    2043
# 5    1835
# 9    1151
# 6     996
# 8     785
# 1     758
# 2     748
# 4     402
# 7     356
# 3     159
# Name: lda_topics, dtype: int64

# %%
df.hist('lda_topics')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c8fff98>]], dtype=object)

# %%
def topic_extraction(df, col_name):
    """
    Two algorithms for topic extraction -
    NMF and LatentDirichletAllocation(LDA).
    Need to tie in with K-means clustering
    """

    tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                       max_features=200,
                                       stop_words='english')
    tfidf = tfidf_vectorizer.fit_transform(df[col_name])
    tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                    max_features=200,
                                    stop_words='english')
    tf = tf_vectorizer.fit_transform(df[col_name])

    nmf = NMF(n_components=6, random_state=1,
            alpha=.1, l1_ratio=.5)
    tfidf_feature_names = tfidf_vectorizer.get_feature_names()
    nmf_w = nmf.fit_transform(tfidf)
    nmf_h = nmf.components_
    labels = nmf_w.argmax(axis=1)
    df['labels2'] = labels # this was the right code to get labels/clusters
#     labels = df['labels'].values

    # tsne_algorithm(tfidf) # feed the tsne algorithm
    # sns.distplot(df['labels'], kde=True)
    # plt.show()
    print("\nTopics in NMF model:")
    print_top_words(nmf, tfidf_feature_names)
#     clustering_algorithm(nmf_w_short, labels)
    """uncomment to LDA topics"""
    lda = LatentDirichletAllocation(n_components=6, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0,
                                n_jobs=-1)
    mod = lda.fit(tf)
    comp = mod.fit_transform(tf)
    lda_labels = comp.argmax(axis=1)
    df['lda_topics2'] = lda_labels
    print("\nTopics in LDA model:")
    tf_feature_names = tf_vectorizer.get_feature_names()
    print_top_words(lda, tf_feature_names)
    
    return df, labels, lda_labels, tfidf, tf
    

def print_top_words(model, feature_names, n_top_words=20):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print('End')

# %%
df2, labels2, lda_labels2, tfidf, tf = topic_extraction(df, 'recipe')
# Out:
# Topics in NMF model:
# Topic #0:
# chopped diced chicken cup onion cups cut peeled sliced finely red medium large pepper small cloves fresh garlic inch pound
# Topic #1:
# cup cups sugar flour butter purpose water vanilla baking unsalted milk teaspoon extract egg tablespoons eggs salt cream teaspoons plus
# Topic #2:
# grams flour piece ounces coconut sugar pinch yeast pieces finely oil egg plus chocolate fine water eggs chopped 10 temperature
# Topic #3:
# teaspoon ground powder teaspoons pepper cumin black dried paprika cinnamon salt cayenne tablespoon coriander seeds garlic chili kosher freshly ginger
# Topic #4:
# sauce tablespoons tablespoon soy sesame vinegar minced ginger rice oil cup garlic sugar chicken teaspoons brown pork pounds honey lime
# Topic #5:
# olive lemon fresh tablespoons oil juice freshly pepper extra salt virgin cup black taste ounces tablespoon ground kosher grated cheese
# End
#
# Topics in LDA model:
# Topic #0:
# chopped cups cut cup diced onion peeled large pepper chicken tablespoons fresh inch salt garlic sliced oil small medium red
# Topic #1:
# cup fresh oil tablespoons olive salt pepper sliced chopped cheese tablespoon garlic grated lemon extra pound freshly taste ounces thinly
# Topic #2:
# cup teaspoon cups sugar powder milk salt ground coconut baking cinnamon flour tablespoons butter vanilla teaspoons tablespoon lemon zest extract
# Topic #3:
# tablespoons cup sauce tablespoon sugar soy brown vinegar sesame rice ginger oil ounces syrup water teaspoon grams juice ounce teaspoons
# Topic #4:
# cup flour cups butter grams tablespoons salt teaspoon unsalted cream ounces sugar purpose water egg teaspoons plus large eggs milk
# Topic #5:
# teaspoon pepper tablespoons ground tablespoon cup salt chicken garlic teaspoons minced oil black onion cloves powder pound sauce dried pounds
# End

# %%
""" LDA labels used to identify points in scatter plot of t-SNE analysis of recipe text"""
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x2, y2, z2, zdir='z', c=lda_labels2, s=20, cmap='Dark2', alpha=0.4)
ax.set_title('TSNE analysis of Recipe Ingredients - LDA labels(6)', fontsize=14, fontweight='bold')
ax.grid(False)
# plt.savefig('data/title_tsne.png')

# %%
""" NMF labels used to identify points in scatter plot of t-SNE analysis of recipe text"""
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, zdir='z', c=labels2, s=20, cmap='Dark2', alpha=0.4)
ax.set_title('TSNE analysis of Recipe Ingredients - NMF labels(6)', fontsize=14, fontweight='bold')
ax.grid(False)
# plt.savefig('data/title_tsne.png')

# %%
rec_stop ="cup cups tablespoon tablespoons teaspoon teaspoons pounds ounces grams gram kilograms kilogram liter liters sliced diced minced finely coarsely roughly cut peeled chopped".split()

# %%
rec_stop
# Out:
# ['cup',
#  'cups',
#  'tablespoon',
#  'tablespoons',
#  'teaspoon',
#  'teaspoons',
#  'pounds',
#  'ounces',
#  'grams',
#  'gram',
#  'kilograms',
#  'kilogram',
#  'liter',
#  'liters',
#  'sliced',
#  'diced',
#  'minced',
#  'finely',
#  'coarsely',
#  'roughly',
#  'cut',
#  'peeled',
#  'chopped']

# %%
from sklearn.feature_extraction import text
def topic_extraction(df, col_name):
    """
    Two algorithms for topic extraction -
    NMF and LatentDirichletAllocation(LDA).
    Need to tie in with K-means clustering
    """
    my_stop_words = text.ENGLISH_STOP_WORDS.union(rec_stop)
    tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                       max_features=200,
                                       analyzer='word',
                                       stop_words=my_stop_words)
    tfidf = tfidf_vectorizer.fit_transform(df[col_name])
    tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                    max_features=200,
                                    stop_words=my_stop_words)
    tf = tf_vectorizer.fit_transform(df[col_name])

    nmf = NMF(n_components=6, random_state=1,
            alpha=.1, l1_ratio=.5)
    tfidf_feature_names = tfidf_vectorizer.get_feature_names()
    nmf_w = nmf.fit_transform(tfidf)
    nmf_h = nmf.components_
    labels = nmf_w.argmax(axis=1)
    df['labels2'] = labels # this was the right code to get labels/clusters
#     labels = df['labels'].values

    # tsne_algorithm(tfidf) # feed the tsne algorithm
    # sns.distplot(df['labels'], kde=True)
    # plt.show()
    print("\nTopics in NMF model:")
    print_top_words(nmf, tfidf_feature_names)
#     clustering_algorithm(nmf_w_short, labels)
    """uncomment to LDA topics"""
    lda = LatentDirichletAllocation(n_components=6, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0,
                                n_jobs=-1)
    mod = lda.fit(tf)
    comp = mod.fit_transform(tf)
    lda_labels = comp.argmax(axis=1)
    df['lda_topics2'] = lda_labels
    print("\nTopics in LDA model:")
    tf_feature_names = tf_vectorizer.get_feature_names()
    print_top_words(lda, tf_feature_names)
    
    return df, labels, lda_labels, tfidf, tf
    

def print_top_words(model, feature_names, n_top_words=20):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print('End')

# %%
topic_extraction(df, 'recipe')

# %%
df4, labels4, lda_labels4, tfidf, tf = topic_extraction(df, 'recipe')
# Out:
# Topics in NMF model:
# Topic #0:
# oil olive chicken pepper garlic red fresh large salt onion cloves small taste medium leaves white wine tomatoes thyme dried
# Topic #1:
# flour sugar butter purpose baking vanilla unsalted extract water powder salt egg milk eggs plus soda room temperature cold granulated
# Topic #2:
# sauce soy sesame rice ginger oil vinegar sugar garlic brown chicken pork chili seeds green water lime vegetable cloves honey
# Topic #3:
# lemon juice fresh zest lime ounce orange freshly mint honey sugar olive water taste leaves garnish salt oil syrup pinch
# Topic #4:
# ground black freshly pepper powder pound beef cumin salt kosher cinnamon pork dried paprika coriander cayenne garlic chili cloves onion
# Topic #5:
# cheese grated cream parmesan slices shredded bread heavy butter milk pound eggs fresh bacon egg pepper sour cooked thinly salt
# End
#
# Topics in LDA model:
# Topic #0:
# sauce oil chicken garlic powder ginger soy green rice red onion chili cloves pepper hot sesame cilantro fresh pieces water
# Topic #1:
# flour salt butter milk purpose egg sugar water unsalted eggs baking powder plus oil cold beaten coconut large vanilla ground
# Topic #2:
# sugar brown ground salt dark room butter temperature cream apple cinnamon cider light vanilla vinegar egg granulated heavy chocolate unsalted
# Topic #3:
# juice lemon ounce fresh zest good orange preferably lime organic quality water garnish used use honey dried freshly 15 sugar
# Topic #4:
# salt fresh pepper oil half leaves dried olive inch ground black lemon small garlic potatoes large seeds medium juice cloves
# Topic #5:
# pepper salt oil ground olive garlic chicken onion fresh pound black cloves red beef large cheese taste white tomatoes freshly
# End

# %%
x5, y5, z5 = clustering_algorithm(tf, labels)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9233 samples in 0.019s...
# [t-SNE] Computed neighbors for 9233 samples in 0.336s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9233
# [t-SNE] Computed conditional probabilities for sample 2000 / 9233
# [t-SNE] Computed conditional probabilities for sample 3000 / 9233
# [t-SNE] Computed conditional probabilities for sample 4000 / 9233
# [t-SNE] Computed conditional probabilities for sample 5000 / 9233
# [t-SNE] Computed conditional probabilities for sample 6000 / 9233
# [t-SNE] Computed conditional probabilities for sample 7000 / 9233
# [t-SNE] Computed conditional probabilities for sample 8000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9233 / 9233
# [t-SNE] Mean sigma: 0.064761
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.958397
# [t-SNE] Error after 1000 iterations: 0.582283

# %%
""" LDA labels used to identify points in scatter plot of t-SNE analysis of recipe text"""
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
# define the colormap
# N = 6
# cmap = plt.cm.jet
# # extract all colors from the .jet map
# cmaplist = [cmap(i) for i in range(cmap.N)]
# # create the new map
# cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)
ax.scatter(x5, y5, z5, zdir='z', c=lda_labels4, s=20, cmap='Set1', alpha=0.4)
ax.set_title('TSNE analysis of Recipe Ingredients - LDA labels(6B)', fontsize=14, fontweight='bold')
ax.grid(False)

plt.savefig('data/recipe_ldalabels_tsne.png')

# %%
x6, y6, z6 = clustering_algorithm(tfidf, labels)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9233 samples in 0.009s...
# [t-SNE] Computed neighbors for 9233 samples in 0.318s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9233
# [t-SNE] Computed conditional probabilities for sample 2000 / 9233
# [t-SNE] Computed conditional probabilities for sample 3000 / 9233
# [t-SNE] Computed conditional probabilities for sample 4000 / 9233
# [t-SNE] Computed conditional probabilities for sample 5000 / 9233
# [t-SNE] Computed conditional probabilities for sample 6000 / 9233
# [t-SNE] Computed conditional probabilities for sample 7000 / 9233
# [t-SNE] Computed conditional probabilities for sample 8000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9000 / 9233
# [t-SNE] Computed conditional probabilities for sample 9233 / 9233
# [t-SNE] Mean sigma: 0.007847
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.588409
# [t-SNE] Error after 1000 iterations: 0.595807

# %%
""" NMF labels used to identify points in scatter plot of t-SNE analysis of recipe text"""
import matplotlib.patches as mpatches
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
# unique = list(set(labels4))
# cmap = [color for color in color_dict.values()[]]
ax.scatter(x6, y6, z6, zdir='z', c=labels4, cmap='Set1', s=20, alpha=0.4)
ax.set_title('TSNE analysis of Recipe Ingredients - NMF labels(6B)', fontsize=14, fontweight='bold')
ax.grid(False)
# red_patch = mpatches.Patch(color=color_dict.values(), label=color_dict.keys())
# ax.legend(handles=[red_patch])
# ax.legend(unique, cmap.colors)
plt.show()
plt.savefig('data/recipe_nmfclustering_tsne.png')

# %%
# import tensorflow as tf

# %%
from itertools import zip_longest

# %%
color_dict = {color: color for color in ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628','#f781bf']}

# %%
lab = list(set(labels))

# %%
color_dict
# Out:
# {'#377eb8': '#377eb8',
#  '#4daf4a': '#4daf4a',
#  '#984ea3': '#984ea3',
#  '#a65628': '#a65628',
#  '#e41a1c': '#e41a1c',
#  '#f781bf': '#f781bf',
#  '#ff7f00': '#ff7f00',
#  '#ffff33': '#ffff33'}

# %%
import numpy as np
import holoviews as hv
hv.extension('matplotlib')
# Out:
# <script src="https://code.jquery.com/ui/1.10.4/jquery-ui.min.js" type="text/javascript"></script>
# <script type="text/javascript">function HoloViewsWidget(){
# }
#
# HoloViewsWidget.comms = {};
# HoloViewsWidget.comm_state = {};
#
# HoloViewsWidget.prototype.init_slider = function(init_val){
#   if(this.load_json) {
#     this.from_json()
#   } else {
#     this.update_cache();
#   }
# }
#
# HoloViewsWidget.prototype.populate_cache = function(idx){
#   this.cache[idx].html(this.frames[idx]);
#   if (this.embed) {
#     delete this.frames[idx];
#   }
# }
#
# HoloViewsWidget.prototype.process_error = function(msg){
#
# }
#
# HoloViewsWidget.prototype.from_json = function() {
#   var data_url = this.json_path + this.id + '.json';
#   $.getJSON(data_url, $.proxy(function(json_data) {
#     this.frames = json_data;
#     this.update_cache();
#     this.update(0);
#   }, this));
# }
#
# HoloViewsWidget.prototype.dynamic_update = function(current){
#   if (current === undefined) {
#     return
#   }
#   if(this.dynamic) {
#     current = JSON.stringify(current);
#   }
#   function callback(initialized, msg){
#     /* This callback receives data from Python as a string
#        in order to parse it correctly quotes are sliced off*/
#     if (msg.content.ename != undefined) {
#       this.process_error(msg);
#     }
#     if (msg.msg_type != "execute_result") {
#       console.log("Warning: HoloViews callback returned unexpected data for key: (", current, ") with the following content:", msg.content)
#     } else {
#       if (msg.content.data['text/plain'].includes('Complete')) {
#         if (this.queue.length > 0) {
#           this.time = Date.now();
#           this.dynamic_update(this.queue[this.queue.length-1]);
#           this.queue = [];
#         } else {
#           this.wait = false;
#         }
#         return
#       }
#     }
#   }
#   this.current = current;
#   if ((window.Jupyter !== undefined) && (Jupyter.notebook.kernel != null)) {
#     var kernel = Jupyter.notebook.kernel;
#     callbacks = {iopub: {output: $.proxy(callback, this, this.initialized)}};
#     var cmd = "holoviews.plotting.widgets.NdWidget.widgets['" + this.id + "'].update(" + current + ")";
#     kernel.execute("import holoviews;" + cmd, callbacks, {silent : false});
#   }
# }
#
# HoloViewsWidget.prototype.update_cache = function(force){
#   var frame_len = Object.keys(this.frames).length;
#   for (var i=0; i<frame_len; i++) {
#     if(!this.load_json || this.dynamic)  {
#       frame = Object.keys(this.frames)[i];
#     } else {
#       frame = i;
#     }
#     if(!(frame in this.cache) || force) {
#       if ((frame in this.cache) && force) { this.cache[frame].remove() }
#       this.cache[frame] = $('<div />').appendTo("#"+"_anim_img"+this.id).hide();
#       var cache_id = "_anim_img"+this.id+"_"+frame;
#       this.cache[frame].attr("id", cache_id);
#       this.populate_cache(frame);
#     }
#   }
# }
#
# HoloViewsWidget.prototype.update = function(current){
#   if(current in this.cache) {
#     $.each(this.cache, function(index, value) {
#       value.hide();
#     });
#     this.cache[current].show();
#     this.wait = false;
#   }
# }
#
# HoloViewsWidget.prototype.init_comms = function() {
#   if ((window.Jupyter !== undefined) && (Jupyter.notebook.kernel !== undefined)) {
#     var widget = this;
#     comm_manager = Jupyter.notebook.kernel.comm_manager;
#     comm_manager.register_target(this.id, function (comm) {
#       comm.on_msg(function (msg) { widget.process_msg(msg) });
#     });
#   }
# }
#
# HoloViewsWidget.prototype.process_msg = function(msg) {
# }
#
# function SelectionWidget(frames, id, slider_ids, keyMap, dim_vals, notFound, load_json, mode, cached, json_path, dynamic){
#   this.frames = frames;
#   this.id = id;
#   this.slider_ids = slider_ids;
#   this.keyMap = keyMap
#   this.current_frame = 0;
#   this.current_vals = dim_vals;
#   this.load_json = load_json;
#   this.mode = mode;
#   this.notFound = notFound;
#   this.cached = cached;
#   this.dynamic = dynamic;
#   this.cache = {};
#   this.json_path = json_path;
#   this.init_slider(this.current_vals[0]);
#   this.queue = [];
#   this.wait = false;
#   if (!this.cached || this.dynamic) {
#     this.init_comms()
#   }
# }
#
# SelectionWidget.prototype = new HoloViewsWidget;
#
#
# SelectionWidget.prototype.get_key = function(current_vals) {
#   var key = "(";
#   for (var i=0; i<this.slider_ids.length; i++)
#   {
#     val = this.current_vals[i];
#     if (!(typeof val === 'string')) {
#       if (val % 1 === 0) { val = val.toFixed(1); }
#       else { val = val.toFixed(10); val = val.slice(0, val.length-1);}
#     }
#     key += "'" + val + "'";
#     if(i != this.slider_ids.length-1) { key += ', ';}
#     else if(this.slider_ids.length == 1) { key += ',';}
#   }
#   key += ")";
#   return this.keyMap[key];
# }
#
# SelectionWidget.prototype.set_frame = function(dim_val, dim_idx){
#   this.current_vals[dim_idx] = dim_val;
#   var key = this.current_vals;
#   if (!this.dynamic) {
#     key = this.get_key(key)
#   }
#   if (this.dynamic || !this.cached) {
#     if ((this.time !== undefined) && ((this.wait) && ((this.time + 10000) > Date.now()))) {
#       this.queue.push(key);
#       return
#     }
#     this.queue = [];
#     this.time = Date.now();
#     this.current_frame = key;
#     this.wait = true;
#     this.dynamic_update(key)
#   } else if (key !== undefined) {
#     this.update(key)
#   }
# }
#
#
# /* Define the ScrubberWidget class */
# function ScrubberWidget(frames, num_frames, id, interval, load_json, mode, cached, json_path, dynamic){
#   this.slider_id = "_anim_slider" + id;
#   this.loop_select_id = "_anim_loop_select" + id;
#   this.id = id;
#   this.interval = interval;
#   this.current_frame = 0;
#   this.direction = 0;
#   this.dynamic = dynamic;
#   this.timer = null;
#   this.load_json = load_json;
#   this.mode = mode;
#   this.cached = cached;
#   this.frames = frames;
#   this.cache = {};
#   this.length = num_frames;
#   this.json_path = json_path;
#   document.getElementById(this.slider_id).max = this.length - 1;
#   this.init_slider(0);
#   this.wait = false;
#   this.queue = [];
#   if (!this.cached || this.dynamic) {
#     this.init_comms()
#   }
# }
#
# ScrubberWidget.prototype = new HoloViewsWidget;
#
# ScrubberWidget.prototype.set_frame = function(frame){
#   this.current_frame = frame;
#   widget = document.getElementById(this.slider_id);
#   if (widget === null) {
#     this.pause_animation();
#     return
#   }
#   widget.value = this.current_frame;
#   if(this.cached) {
#     this.update(frame)
#   } else {
#     this.dynamic_update(frame)
#   }
# }
#
#
# ScrubberWidget.prototype.get_loop_state = function(){
#   var button_group = document[this.loop_select_id].state;
#   for (var i = 0; i < button_group.length; i++) {
#     var button = button_group[i];
#     if (button.checked) {
#       return button.value;
#     }
#   }
#   return undefined;
# }
#
#
# ScrubberWidget.prototype.next_frame = function() {
#   this.set_frame(Math.min(this.length - 1, this.current_frame + 1));
# }
#
# ScrubberWidget.prototype.previous_frame = function() {
#   this.set_frame(Math.max(0, this.current_frame - 1));
# }
#
# ScrubberWidget.prototype.first_frame = function() {
#   this.set_frame(0);
# }
#
# ScrubberWidget.prototype.last_frame = function() {
#   this.set_frame(this.length - 1);
# }
#
# ScrubberWidget.prototype.slower = function() {
#   this.interval /= 0.7;
#   if(this.direction > 0){this.play_animation();}
#   else if(this.direction < 0){this.reverse_animation();}
# }
#
# ScrubberWidget.prototype.faster = function() {
#   this.interval *= 0.7;
#   if(this.direction > 0){this.play_animation();}
#   else if(this.direction < 0){this.reverse_animation();}
# }
#
# ScrubberWidget.prototype.anim_step_forward = function() {
#   if(this.current_frame < this.length - 1){
#     this.next_frame();
#   }else{
#     var loop_state = this.get_loop_state();
#     if(loop_state == "loop"){
#       this.first_frame();
#     }else if(loop_state == "reflect"){
#       this.last_frame();
#       this.reverse_animation();
#     }else{
#       this.pause_animation();
#       this.last_frame();
#     }
#   }
# }
#
# ScrubberWidget.prototype.anim_step_reverse = function() {
#   if(this.current_frame > 0){
#     this.previous_frame();
#   } else {
#     var loop_state = this.get_loop_state();
#     if(loop_state == "loop"){
#       this.last_frame();
#     }else if(loop_state == "reflect"){
#       this.first_frame

# %%
hv.Scatter3D((x6, y6, z6))
# Out:
# :Scatter3D   [x,y,z]

# %%
fig = plt.figure(figsize=(15, 15))
hv = fig.add_subplot(111, projection='3d')
hv.scatter(x6, y6, z6, zdir='z', c=labels4, s=20, cmap='Set1', alpha=0.4)
hv.set_title('TSNE analysis of Recipe Ingredients - NMF labels(6B)', fontsize=14, fontweight='bold')
hv.grid(False)
hv.legend()
plt.savefig('data/recipe_nmfclustering_tsne.png')
# Out:
# /Applications/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
cmap = plt.cm.get_cmap("Set1", 6)

# %%
cmap.
# Out:
# 9

# %%
df.head()
# Out:
#                         _id  rating  \
# 0  59d7cf29a980892888190548      14
# 1  59d7cf30a98089288819054a      29
# 2  59d7cf39a98089288819054c       2
# 3  59d7cf3fa98089288819054e      92
# 4  59d7cf48a980892888190550       3
#
#                                               recipe  \
# 0  2 tablespoons unsalted butter\n1/4 cup diced y...
# 1  1 pound shelled raw peanuts\n1 tablespoon plus...
# 2  2 cups (8 1/2 ounces) all-purpose flour\n1/2 c...
# 3  1 1/2 cups (300g) Puy lentils, washed\n4 clove...
# 4  2 ounces Seedlip Garden 108\n0.75 ounces Lemon...
#
#                                                title  \
# 0                           Austin Diner-Style Queso
# 1                Mamba (Spicy Haitian Peanut Butter)
# 2                                  Sheet Pan Muffins
# 3  Anna Jones' Favorite Lentils with Roasted Toma...
# 4                              Seedlip's A Good Dill
#
#                                              weblink  labels  lda_topics  \
# 0  https://food52.com/recipes/73529-austin-diner-...       0           0
# 1  https://food52.com/recipes/73211-mamba-spicy-h...       3           5
# 2  https://food52.com/recipes/73548-sheet-pan-muf...       1           8
# 3  https://food52.com/recipes/73511-anna-jones-fa...       5           0
# 4  https://food52.com/recipes/73252-seedlip-s-a-g...       7           3
#
#    labels2  lda_topics2
# 0        5            1
# 1        4            1
# 2        1            5
# 3        0            1
# 4        3            0

# %%
df2 = pd.read_csv('data/food52_addenda_transformed.csv')

# %%
df2.reset_index(inplace=True)

# %%
del df2['index']
del df2['Unnamed: 0']

# %%
df2.head()
# Out:
#        date_submitted  rating  servings  \
# 0      April 14, 2011      55       4.0
# 1     October 3, 2016       1       NaN
# 2     August 13, 2014       3       NaN
# 3     October 4, 2017      64      68.0
# 4  September 18, 2017      38       1.0
#
#                                        title  \
# 0  Beef Stroganoff with Mushrooms and Onions
# 1          Asian Sliders with Gochujang Mayo
# 2                   Ground Turkey Stroganoff
# 3                   Austin Diner-Style Queso
# 4        Mamba (Spicy Haitian Peanut Butter)
#
#                                        user_comments  number_comments  \
# 0  ["\n\nabout 3 years ago\nCampCook\n\nThere is ...                5
# 1                                                 []                0
# 2  ['\n\n10 months ago\nHodie-Hi\n\nIngredients l...                2
# 3  ['\n\n23 days ago\nalex\n\nDo as the locals do...                8
# 4  ['\n\n26 days ago\nRegine\n\n“Cooking in HMB,”...                6
#
#   date_formatted
# 0     2011-04-14
# 1     2011-04-14
# 2     2011-04-14
# 3     2011-04-14
# 4     2011-04-14

# %%
new_df = df.merge(df2, how='left', on='title')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9235 entries, 0 to 9234
# Data columns (total 15 columns):
# _id                9235 non-null object
# rating_x           9235 non-null int64
# recipe             9235 non-null object
# title              9235 non-null object
# weblink            9235 non-null object
# labels             9235 non-null int64
# lda_topics         9235 non-null int64
# labels2            9235 non-null int64
# lda_topics2        9235 non-null int64
# date_submitted     9235 non-null object
# rating_y           9235 non-null int64
# servings           7437 non-null float64
# user_comments      9235 non-null object
# number_comments    9235 non-null int64
# date_formatted     9235 non-null object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 1.1+ MB

# %%
del new_df['servings']

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9235 entries, 0 to 9234
# Data columns (total 14 columns):
# _id                9235 non-null object
# rating_x           9235 non-null int64
# recipe             9235 non-null object
# title              9235 non-null object
# weblink            9235 non-null object
# labels             9235 non-null int64
# lda_topics         9235 non-null int64
# labels2            9235 non-null int64
# lda_topics2        9235 non-null int64
# date_submitted     9235 non-null object
# rating_y           9235 non-null int64
# user_comments      9235 non-null object
# number_comments    9235 non-null int64
# date_formatted     9235 non-null object
# dtypes: int64(7), object(7)
# memory usage: 1.1+ MB

# %%
new_df.head()
# Out:
#                         _id  rating_x  \
# 0  59d7cf29a980892888190548        14
# 1  59d7cf30a98089288819054a        29
# 2  59d7cf39a98089288819054c         2
# 3  59d7cf3fa98089288819054e        92
# 4  59d7cf48a980892888190550         3
#
#                                               recipe  \
# 0  2 tablespoons unsalted butter\n1/4 cup diced y...
# 1  1 pound shelled raw peanuts\n1 tablespoon plus...
# 2  2 cups (8 1/2 ounces) all-purpose flour\n1/2 c...
# 3  1 1/2 cups (300g) Puy lentils, washed\n4 clove...
# 4  2 ounces Seedlip Garden 108\n0.75 ounces Lemon...
#
#                                                title  \
# 0                           Austin Diner-Style Queso
# 1                Mamba (Spicy Haitian Peanut Butter)
# 2                                  Sheet Pan Muffins
# 3  Anna Jones' Favorite Lentils with Roasted Toma...
# 4                              Seedlip's A Good Dill
#
#                                              weblink  labels  lda_topics  \
# 0  https://food52.com/recipes/73529-austin-diner-...       0           0
# 1  https://food52.com/recipes/73211-mamba-spicy-h...       3           5
# 2  https://food52.com/recipes/73548-sheet-pan-muf...       1           8
# 3  https://food52.com/recipes/73511-anna-jones-fa...       5           0
# 4  https://food52.com/recipes/73252-seedlip-s-a-g...       7           3
#
#    labels2  lda_topics2      date_submitted  rating_y  \
# 0        5            1     October 4, 2017        64
# 1        4            1  September 18, 2017        38
# 2        1            5     October 5, 2017        76
# 3        0            1     October 3, 2017       130
# 4        3            0  September 21, 2017         5
#
#                                        user_comments  number_comments  \
# 0  ['\n\n23 days ago\nalex\n\nDo as the locals do...                8
# 1  ['\n\n26 days ago\nRegine\n\n“Cooking in HMB,”...                6
# 2  ["\n\n11 days ago\nGumba\n\nReminds me of HoJo...               14
# 3  ['\n\n18 days ago\nJenn Travis\n\nThese are so...               10
# 4                                                 []                0
#
#   date_formatted                                     clean_comments
# 0     2011-04-14  [\n\n23 days ago\nalex\n\nDo as the locals do:...
# 1     2011-04-14  [\n\n26 days ago\nRegine\n\n“Cooking in HMB,” ...
# 2     2011-04-14  [\n\n11 days ago\nGumba\n\nReminds me of HoJo'...
# 3     2011-04-14  [\n\n18 days ago\nJenn Travis\n\nThese are so ...
# 4     2011-04-14                                                 []

# %%
test = "".join(new_df.iloc[2, 11])

# %%
import ast
test_lst = ast.literal_eval(test)

# %%
new_df['clean_comments'] = new_df['user_comments'].apply(lambda x: ast.literal_eval(x))

# %%
def clean_com(col):
    return [item.split('\n')[3:]for item in col]

# %%
new_df['clean_comments'] = new_df['clean_comments'].apply(clean_com)

# %%
new_df.head()
# Out:
#                         _id  rating_x  \
# 0  59d7cf29a980892888190548        14
# 1  59d7cf30a98089288819054a        29
# 2  59d7cf39a98089288819054c         2
# 3  59d7cf3fa98089288819054e        92
# 4  59d7cf48a980892888190550         3
#
#                                               recipe  \
# 0  2 tablespoons unsalted butter\n1/4 cup diced y...
# 1  1 pound shelled raw peanuts\n1 tablespoon plus...
# 2  2 cups (8 1/2 ounces) all-purpose flour\n1/2 c...
# 3  1 1/2 cups (300g) Puy lentils, washed\n4 clove...
# 4  2 ounces Seedlip Garden 108\n0.75 ounces Lemon...
#
#                                                title  \
# 0                           Austin Diner-Style Queso
# 1                Mamba (Spicy Haitian Peanut Butter)
# 2                                  Sheet Pan Muffins
# 3  Anna Jones' Favorite Lentils with Roasted Toma...
# 4                              Seedlip's A Good Dill
#
#                                              weblink  labels  lda_topics  \
# 0  https://food52.com/recipes/73529-austin-diner-...       0           0
# 1  https://food52.com/recipes/73211-mamba-spicy-h...       3           5
# 2  https://food52.com/recipes/73548-sheet-pan-muf...       1           8
# 3  https://food52.com/recipes/73511-anna-jones-fa...       5           0
# 4  https://food52.com/recipes/73252-seedlip-s-a-g...       7           3
#
#    labels2  lda_topics2      date_submitted  rating_y  \
# 0        5            1     October 4, 2017        64
# 1        4            1  September 18, 2017        38
# 2        1            5     October 5, 2017        76
# 3        0            1     October 3, 2017       130
# 4        3            0  September 21, 2017         5
#
#                                        user_comments  number_comments  \
# 0  ['\n\n23 days ago\nalex\n\nDo as the locals do...                8
# 1  ['\n\n26 days ago\nRegine\n\n“Cooking in HMB,”...                6
# 2  ["\n\n11 days ago\nGumba\n\nReminds me of HoJo...               14
# 3  ['\n\n18 days ago\nJenn Travis\n\nThese are so...               10
# 4                                                 []                0
#
#   date_formatted                                     clean_comments
# 0     2011-04-14  [[alex, , Do as the locals do: On the stovetop...
# 1     2011-04-14  [[Regine, , “Cooking in HMB,” recipe asks for ...
# 2     2011-04-14  [[Gumba, , Reminds me of HoJo's blueberry toas...
# 3     2011-04-14  [[Jenn Travis, , These are so so yummy. They w...
# 4     2011-04-14                                                 []

# %%
senti_df = new_df[['title', 'clean_comments', 'number_comments']]

# %%
def title_mul(col):
    return list(col)

# %%
senti_df['title_mul'] = senti_df['title'].apply(lambda x: [x])
# Out:
# /Applications/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
senti_df['title_mul_f'] = senti_df['title_mul'] * senti_df['number_comments']
# Out:
# /Applications/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
senti_df.head()
# Out:
#                                                title  \
# 0                           Austin Diner-Style Queso
# 1                Mamba (Spicy Haitian Peanut Butter)
# 2                                  Sheet Pan Muffins
# 3  Anna Jones' Favorite Lentils with Roasted Toma...
# 4                              Seedlip's A Good Dill
#
#                                       clean_comments  number_comments  \
# 0  [[alex, , Do as the locals do: On the stovetop...                8
# 1  [[Regine, , “Cooking in HMB,” recipe asks for ...                6
# 2  [[Gumba, , Reminds me of HoJo's blueberry toas...               14
# 3  [[Jenn Travis, , These are so so yummy. They w...               10
# 4                                                 []                0
#
#                                            title_mul  \
# 0                         [Austin Diner-Style Queso]
# 1              [Mamba (Spicy Haitian Peanut Butter)]
# 2                                [Sheet Pan Muffins]
# 3  [Anna Jones' Favorite Lentils with Roasted Tom...
# 4                            [Seedlip's A Good Dill]
#
#                                          title_mul_f
# 0  [Austin Diner-Style Queso, Austin Diner-Style ...
# 1  [Mamba (Spicy Haitian Peanut Butter), Mamba (S...
# 2  [Sheet Pan Muffins, Sheet Pan Muffins, Sheet P...
# 3  [Anna Jones' Favorite Lentils with Roasted Tom...
# 4                                                 []

# %%
comments = senti_df['clean_comments']

# %%
titles = senti_df['title_mul_f']

# %%
combo = []
for n in range(len(comments)):
    comb = list(zip(comments[n], titles[n]))
    combo.extend(comb)

# %%
len(combo)
# Out:
# 52907

# %%
df_working = pd.DataFrame.from_records(combo)

# %%
df_working.head()
# Out:
#                                                    0                         1
# 0  [alex, , Do as the locals do: On the stovetop ...  Austin Diner-Style Queso
# 1  [petalpusher, , This recipe is good for those ...  Austin Diner-Style Queso
# 2  [EmFraiche, , How much water do you add? I don...  Austin Diner-Style Queso
# 3  [Jennifer M, , I put in equal parts milk and w...  Austin Diner-Style Queso
# 4  [Ceil_the_great, , Sounds tasty! Can you recom...  Austin Diner-Style Queso

# %%
df_working.columns = 'user_comment recipe_title'.split()

# %%
df_working.head()
# Out:
#                                         user_comment  \
# 0  [alex, , Do as the locals do: On the stovetop ...
# 1  [petalpusher, , This recipe is good for those ...
# 2  [EmFraiche, , How much water do you add? I don...
# 3  [Jennifer M, , I put in equal parts milk and w...
# 4  [Ceil_the_great, , Sounds tasty! Can you recom...
#
#                recipe_title            user  \
# 0  Austin Diner-Style Queso            alex
# 1  Austin Diner-Style Queso     petalpusher
# 2  Austin Diner-Style Queso       EmFraiche
# 3  Austin Diner-Style Queso      Jennifer M
# 4  Austin Diner-Style Queso  Ceil_the_great
#
#                                              comment
# 0  Do as the locals do: On the stovetop or in the...
# 1  This recipe is good for those of us who are al...
# 2  How much water do you add? I don’t see an amount.
# 3  I put in equal parts milk and water and it see...
# 4  Sounds tasty! Can you recommend a substitute f...

# %%
def user_id(col):
    if col != []:
        return col[0]
    else:
        return None
df_working['user'] = df_working['user_comment'].apply(user_id)

# %%
df_working.iloc[0, 0][-2]
# Out:
# 'Do as the locals do: On the stovetop or in the microwave melt 1 block of velveeta cheese and one can of rotel tomatoes.  If you are feeling fancy you can mix in pickled jalapenos, guacamole, ground beef sauteed with onions, or black beans.  Enjoy with college football.'

# %%
df_working['comment'] = df_working['user_comment'].apply(lambda x: x[-2])

# %%
del df_working['user_comment']

# %%
df_working.to_csv('data/recipe_user_comment.csv')

# %%
import nltk

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [autoreload of six failed: Traceback (most recent call last):
#   File "/Applications/anaconda/envs/py36/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# AttributeError: 'NoneType' object has no attribute 'cStringIO'
# ]
# [autoreload of requests failed: Traceback (most recent call last):
#   File "/Applications/anaconda/envs/py36/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ImportError: cannot import name 'RequestsDependencyWarning'
# ]
# [autoreload of requests.models failed: Traceback (most recent call last):
#   File "/Applications/anaconda/envs/py36/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]
# /Applications/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/contrib/socks.py:37: DependencyWarning: SOCKS support in urllib3 requires the installation of optional dependencies: specifically, PySocks.  For more information, see https://urllib3.readthedocs.io/en/latest/contrib.html#socks-proxies
#   DependencyWarning
# /Applications/anaconda/envs/py36/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
slc = SentimentIntensityAnalyzer()

# %%
slc.polarity_scores('I am a blah')
# Out:
# {'compound': -0.1027, 'neg': 0.583, 'neu': 0.417, 'pos': 0.0}

# %%
def sentence_pos(col):
    return slc.polarity_scores(col)

# %%
df_working['pol_scores'] = df_working['comment'].apply(sentence_pos)

# %%
df_working['pol_scores'][0]
# Out:
# {'compound': 0.2023, 'neg': 0.056, 'neu': 0.853, 'pos': 0.091}

# %%
df_working['compound'] = df_working['pol_scores'].apply(lambda x: x['compound'])

# %%
def implicit(col):
    if col <= 0:
        return 0
    if col > 0 and col <= 0.3:
        return 1
    if col > 0.3 and col <= 0.6:
        return 2
    if col > 0.6:
        return 3
df_working['implicit'] = df_working['compound'].apply(implicit)

# %%
df_working['implicit'].value_counts()
# Out:
# 3    29026
# 0    13538
# 2     8228
# 1     2115
# Name: implicit, dtype: int64

# %%
df_working['implicit'].mean()
# Out:
# 1.9968813200521671

# %%
df_working.to_csv('data/implicit_ratings.csv')

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.hist(df_working['implicit'])
ax.grid(False)
ax.set_title('Implicit Rating Distribution', fontsize=16, fontweight='bold')
ax.set_ylabel('Counts', fontsize=14, fontweight='bold')
ax.set_xlabel('Ratings', fontsize=14, fontweight='bold')

# %%
df_working['implicit'].value_counts()
# Out:
# 3    29026
# 0    13538
# 2     8228
# 1     2115
# Name: implicit, dtype: int64

# %%
df_working.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52907 entries, 0 to 52906
# Data columns (total 6 columns):
# recipe_title    52907 non-null object
# user            52907 non-null object
# comment         52907 non-null object
# pol_scores      52907 non-null object
# compound        52907 non-null float64
# implicit        52907 non-null int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.4+ MB
